# %%
import modules.notebook as notebook

# %%
notebook.run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# E:\Python\JustMecha\modules\notebook.py in __get_data()
#      15     try:
# ---> 16         __is_update_needed()
#      17
#
# E:\Python\JustMecha\modules\notebook.py in __is_update_needed()
#      32
# ---> 33     with open('data/data_save.txt') as date_file:
#      34         date: str = date_file.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/data_save.txt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# E:\Python\JustMecha\modules\notebook.py in __create_dataframe()
#      47     try:
# ---> 48         dataframe = pd.read_csv('data/products.csv', names=header)
#      49     except Exception:
#
# ...
